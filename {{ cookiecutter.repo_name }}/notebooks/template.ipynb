# %% [markdown]
# # TICKETNUMBER: Title of the Notebook
#
# ## Description
#
# - What is this notebook for?
# - What is the goal?
#
# ## Table of Contents
#
# - Is this a thing I can do automatically?

# %%
import os
import json

import numpy as np
import pandas as pd
